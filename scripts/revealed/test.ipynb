# %% [markdown]
# # Test notebook for CES androids

# %%
using Pkg
Pkg.activate("../")
# Out:
#   Activating project at `~/workspace/ExchangeMarket.jl/scripts`

# %%
using Revise
using Random, SparseArrays, LinearAlgebra
using JuMP, MosekTools
using Plots, LaTeXStrings, Printf
import MathOptInterface as MOI

using ExchangeMarket

include("../tools.jl")
include("../plots.jl")
include("./plc.jl")
include("./setup.jl")

switch_to_pdf(; bool_use_html=true)
# Out:
# :html

# %% [markdown]
# # Test Column-Generation Procedure
#
# - use a underlying market f1, to generate $\Xi$,
# - then, create a surrogate market fa, initialized with one agent
# - use CG to iteratively add agents

# %%
m = 10
n = 5
K = 30 # how many revealed preferences pairs we have
market_type = :plc
seed = 5
if market_type === :ces
    ρ_vec = -3.5 .+ 4.3 .* rand(m)
    f0 = let
        ws = cpu_workspace(n)
        add_ces!(ws, m; ρ=ρ_vec, scale=30.0, sparsity=0.99)
        ws.ces.w ./= sum(ws.ces.w)
        FisherMarket(ws)
    end
    linconstr = LinearConstr(1, n, ones(1, n), [1.0])
    f1 = copy(f0)
    p₀ = ones(n) ./ n
    f1.x .= ones(n, m) ./ m
    alg = HessianBar(n, m, p₀; linconstr=linconstr)
    alg.linsys = :direct
    @info "Ground-truth CES market" n m K σ_range = extrema(f1.σ)
    Ξ_train = produce_revealed_preferences(alg, f1, K; seed=seed)
    Ξ_test = produce_revealed_preferences(alg, f1, K; seed=seed + 1)
elseif market_type === :plc
    L = 5
    intercept = true
    plc_agents = [random_plc_agent(n, L; intercept=intercept) for _ in 1:m]
    w_vec = rand(m)
    w_vec ./= sum(w_vec)
    @info "Ground-truth PLC market" n m L K intercept
    @info "producing training set..."
    Ξ_train = produce_revealed_preferences_plc(plc_agents, w_vec, K, n; seed=seed)
    @info "producing test set..."
    Ξ_test = produce_revealed_preferences_plc(plc_agents, w_vec, K, n; seed=seed + 1)
else
    error("Unknown market_type: $market_type")
end
# Out:
# ┌ Info: Ground-truth PLC market
# │   n = 5
# │   m = 10
# │   L = 5
# │   K = 30
# │   intercept = true
# └ @ Main /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:24
# ┌ Info: producing training set...
# └ @ Main /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:25
# ┌ Info: producing test set...
# └ @ Main /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:27
# 30-element Vector{Tuple{Vector{Float64}, Vector{Float64}}}:
#  ([0.3581489557255126, 0.1274116053232256, 0.27405099462463794, 0.10602489189953021, 0.1343635524270936], [0.0, 3.0700014375430102, 0.4625690606345561, 1.4295797679546574, 2.4598012706514107])
# ...

# %%
# Run standard CG (no test set)
Random.seed!(42)
cg_kwargs = Dict(
    :max_iters => 50,
    :tol_obj => 1e-3,
    :tol_rc => 1e-3,
    :tol_delta => 1e-3,
    :drop => false,
    :classes => [:ces, :linear, :leontief]
)
@time fa_cg, γ_ref_cg, hist_cg = run_method_tracked(
    :CG, :cg_single, cg_kwargs, Ξ; verbose=true
);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# === CG (cg_single) ===
#     k |      train |       test | red. cost. |      Δ(fp) |     T |          class |       t(s)
# ------+------------+------------+------------+------------+-------+----------------+-----------
# Set parameter Username
# Set parameter LicenseID to value 2821978
# Academic license - for non-commercial use only - expires 2027-05-13
#     1 |  3.452e-01 |          - |  1.671e+01 |  0.000e+00 |     2 |         ces(1) |     0.0250
# Set parameter Username
# Set parameter LicenseID to value 2821978
# Academic license - for non-commercial use only - expires 2027-05-13
#     2 |  2.303e-01 |          - |  1.800e+01 |  1.149e-01 |     3 |         ces(1) |     0.0556
# Set parameter Username
# Set parameter LicenseID to value 2821978
# Academic license - for non-commercial use only - expires 2027-05-13
# ...

# %%
@agent fa_cg 2 ρ
# Out:
# 1.0

# %%
# Run multicut CG (no test set)
Random.seed!(42)
mc_kwargs = Dict(
    :max_iters => 15,
    :tol_obj => 1e-3,
    :tol_rc => 1e-3,
    :tol_delta => 1e-3,
    :drop => true,
    :classes => [:ces, :linear, :leontief]
)
@time fa_mc, γ_ref_mc, hist_mc = run_method_tracked(
    :Multicut, :cg_multicut, mc_kwargs, Ξ;);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# === Multicut (cg_multicut) ===
#     k |      train |       test | red. cost. |      Δ(fp) |     T |          class |       t(s)
# ------+------------+------------+------------+------------+-------+----------------+-----------
#     1 |  3.452e-01 |          - |          - |  0.000e+00 |    33 | ces×30+ces(1)+ces(-∞) |     0.0298
#     2 |  2.352e-02 |          - |          - |  3.217e-01 |    38 | ces×30+ces(1)+ces(-∞) |     0.5471
#     3 |  4.732e-03 |          - |          - |  1.879e-02 |    47 | ces×30+ces(1)+ces(-∞) |     1.0605
#     4 |  1.019e-03 |          - |          - |  3.713e-03 |    50 | ces×30+ces(1)+ces(-∞) |     1.8680
#     5 |  3.196e-04 |          - |          - |  6.999e-04 |    28 |              - |     1.8828
# converged (obj/K = 3.20e-04 < tol_obj=0.001)
# --- done: 28 agents, obj/K=3.196e-04, t=1.8931s ---
# ...

# %%
# Convergence plot
p1 = plot(hist_cg[:primal_obj], label="CG", lw=2, xlabel="Iteration", ylabel="Primal obj", title="Convergence")
plot!(p1, hist_mc[:primal_obj], label="Multicut", lw=2, ls=:dash)
plot(p1, size=(600, 350))
# Out:
# <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>    <div id="ded507bf-8807-4df6-8f33-8e9d8d27ca09" style="width:600px;height:350px;"></div>
#     <script>
#
#     Plotly.newPlot('ded507bf-8807-4df6-8f33-8e9d8d27ca09', [
#     {
#         "showlegend": true,
#         "mode": "lines",
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.509920634920635,
#             "title": "",
#             "len": 0.8465504311961005,
#             "x": 0.9934383202099737
#         },
#         "name": "CG",
#         "yaxis": "y",
#         "legendgroup": "CG",
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             0.3452376143164745,
#             0.22141056220259442,
#             0.1511205339683502,
#             0.11627650017588054,
#             0.0613497548884877,
#             0.036961161512947156,
# ...

# %%
pn = rand(n)
alg.p .= pn ./ sum(pn)
play!(alg, f1)
gn = sum(f1.x, dims=2)[:]
play!(alg, fa_mc)
ga = sum(fa_mc.x, dims=2)
[alg.p .* gn alg.p .* ga]
# Out:
# 20×2 Matrix{Float64}:
#  0.0491884  0.0487704
#  0.0555653  0.0562526
#  0.0501072  0.0479905
#  0.0414709  0.0410577
#  0.0403206  0.0420239
#  0.0459194  0.0457139
#  0.0403914  0.0408374
#  0.0553908  0.0542595
#  0.0651232  0.0656276
#  0.0571297  0.0592045
#  0.0565524  0.0572626
#  0.059975   0.0606562
#  0.0520578  0.0509358
#  0.0323039  0.0325955
#  0.0377786  0.0381076
#  0.0632416  0.0619785
#  0.0407872  0.0428365
#  0.0514816  0.0517338
#  0.0443599  0.0432617
#  0.0608551  0.0588939
