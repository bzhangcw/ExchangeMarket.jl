# %% [markdown]
# # Test notebook for CES androids

# %%
using Pkg
Pkg.activate("../")
# Out:
#   Activating project at `~/workspace/ExchangeMarket.jl/scripts`

# %%
using Revise
using Random, SparseArrays, LinearAlgebra
using JuMP, MosekTools
using Plots, LaTeXStrings, Printf
import MathOptInterface as MOI

using ExchangeMarket

include("../tools.jl")
include("../plots.jl")
switch_to_pdf(; bool_use_html=true)

include("./util.jl")
# Out:
# ┌ Warning: `PlotlyKaleido` 2.3.0 is not compatible with this version of `Plots`. The declared compatibility is 1.
# └ @ Plots /Users/brent/.julia/packages/Plots/FFuQi/src/backends.jl:55
# Cardinal Optimizer v7.2.4. Build date Dec  6 2024
# Copyright Cardinal Operations 2024. All Rights Reserved
# _linear_prog_ces_gamma_single

# %% [markdown]
# # Basic/Test/Module (could pass)

# %% [markdown]
# ## CES economy in linear conic form

# %%
m = 3
n = 20
ρ = -1.8
b = rand(n, m)
b ./= sum(b; dims=2)
e = ones(n)

# -----------------------------------------------------------------------
# setup market
# -----------------------------------------------------------------------
f0 = FisherMarket(m, n; ρ=ρ * ones(m), scale=30.0, sparsity=0.99)
linconstr = LinearConstr(1, n, ones(1, n), [1.0])

# -----------------------------------------------------------------------
# compute ground truth
# -----------------------------------------------------------------------
f1 = copy(f0)
p₀ = ones(n) ./ (n)
x₀ = ones(n, m) ./ m
f1.x .= x₀
alg = HessianBar(
    n, m, p₀;
    linconstr=linconstr,
)
alg.linsys = :direct
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0061 seconds
# FisherMarket initialized in 0.0265 seconds
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# :direct

# %%
play!(alg, f1)
grad!(alg, f1)
eval!(alg, f1)
hess!(alg, f1)
# Out:
# exact dense Hessian built (heterogeneous σ)

# %% [markdown]
# ### Conic Form

# %%
idx = 1
cr = f1.c[:, idx] .^ (1 / ρ)
xc = _conic_ces_primal(;
    n=f1.n,
    w=f1.w[idx],
    cr=cr,
    p=alg.p,
    ρ=f1.ρ[1],
    verbose=true
)
# Out:
# MOSEK error 20405 (MSK_RES_ERR_DOMAIN_POWER_NEGATIVE_ALPHA): The value of alpha[0] not strictly positive.
# Mosek.MosekError(20405, "The value of alpha[0] not strictly positive.\n")
#
#
#
# Stacktrace:
#
#   [1] appendprimalpowerconedomain
#
#     @ ~/.julia/packages/Mosek/Gzljt/src/msk_functions.jl:3659 [inlined]
#
#   [2] _append_cone_domain(t::Mosek.Task, n::Int64, dom::MathOptInterface.PowerCone{Float64})
#
#     @ MosekTools ~/.julia/packages/MosekTools/hgngi/src/constraint.jl:365
#
#   [3] add_constraint(m::MosekTools.Optimizer, func::MathOptInterface.VectorAffineFunction{Float64}, dom::MathOptInterface.PowerCone{Float64})
#
#     @ MosekTools ~/.julia/packages/MosekTools/hgngi/src/constraint.jl:619
#
# ...

# %%
# should be the same
[xc f1.x[:, idx]]

# %% [markdown]
# ## Exact recovery from the bidding vector

# %%
include("./util.jl")
# Out:
# _linear_prog_ces_gamma_single

# %% [markdown]
# ## Exact formula of CES p to c, given 1

# %%
γ = alg.p .* f1.x[:, 1] ./ f1.w[1]
pmat = zeros(n, 1)
gmat = zeros(n, 1)
pmat[:, 1] .= alg.p
gmat[:, 1] .= γ

# -----------------------------------------------------------------------
# try if I have only one gamma
y, δ, A, md = _linear_prog_ces_gamma_single(pmat=pmat, gmat=gmat, verbose=true)
objective_value(md)
# Out:
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 60
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 43
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 21
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# ...

# %% [markdown]
# ## Exact formula of CES p to c, given many, but provided $\gamma_1,...$
#
# - here I gave K p-gamma pair
# - then use one ces agent to recover
# - because it is generated from a ces player,
# - it should be recoverable

# %%
K = 12
gmat = zeros(n, K)
pmat = zeros(n, K)
zmat = zeros(n, K)
# use the first play
idx = 1
for k = 1:K
    alg.p .= rand(n)
    play!(alg, f1)
    grad!(alg, f1)
    eval!(alg, f1)
    pmat[:, k] .= alg.p
    gmat[:, k] .= alg.p .* f1.x[:, idx] ./ sum(alg.p .* f1.x[:, idx])
    zmat[:, k] .= sum(f1.x, dims=2)
end

# %%
y, δ, A, md = _linear_prog_ces_gamma_single(pmat=pmat, gmat=gmat, δ₁=nothing, verbose=true)
@info "" δ f1.σ
γv(p, a) = begin
    γ = exp.(y) .* (p .^ (-δ))
    γ ./= exp(a)
end
γfit = zeros(n, K)
for k = 1:K
    γfit[:, k] .= γv(pmat[:, k], A[k])
end
@info "optimal value" objective_value(md)
@info "tightness" (gmat - γfit) .|> abs |> maximum

# %%
gmat ./ γfit

# %% [markdown]
# ## Test if primal dual master problem is accurate
#
# - generate $\Xi$ from a FisherMarket with CES agents
# - recover so from $\gamma$, using the same market (assuming we dont know the budgets)
# - the recoverd budgets should agree with the original market because we use the same information

# %%
m = 3
n = 20
ρ = -1.8
b = rand(n, m)
b ./= sum(b; dims=2)
e = ones(n)

# -----------------------------------------------------------------------
# setup market
# -----------------------------------------------------------------------
f0 = FisherMarket(m, n; ρ=ρ * ones(m), scale=30.0, sparsity=0.99)
linconstr = LinearConstr(1, n, ones(1, n), [1.0])

# -----------------------------------------------------------------------
# compute ground truth
# -----------------------------------------------------------------------
f1 = copy(f0)
p₀ = ones(n) ./ (n)
x₀ = ones(n, m) ./ m
f1.x .= x₀
alg = HessianBar(
    n, m, p₀;
    linconstr=linconstr,
)
alg.linsys = :direct
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0000 seconds
# FisherMarket initialized in 0.0001 seconds
# :direct

# %%
include("./master.jl")
include("./pricing.jl")
# Out:
# solve_pricing_dual_lp

# %%
# Generate revealed preferences from the market
K = 12
Ξ = produce_revealed_preferences(alg, f1, K; seed=42)

# Compute bidding matrix from market parameters
γ = compute_gamma_from_market(f1, Ξ)

w, s, model_primal = solve_master_problem(Ξ, γ; verbose=true)
u, μ, model_dual = solve_dual_problem(Ξ, γ; verbose=true)

# Validate strong duality
println("=== Strong Duality Validation ===")
println("Primal objective (Q):     ", objective_value(model_primal))
println("Dual objective (Q_*):     ", objective_value(model_dual))
println("Gap:                      ", abs(objective_value(model_primal) - objective_value(model_dual)))
println()
println("Primal solution w - ground truth:   ", abs.(w - f1.w) |> maximum)
println("Dual solution μ:          ", μ)
println("Dual solution u:          ", u[1:5])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter OutputFlag to value 1
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[arm] - Darwin 25.5.0 25F5042g)
#
# CPU model: Apple M4 Pro
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 481 rows, 255 columns and 1431 nonzeros
# Model fingerprint: 0x021eec83
# Coefficient statistics:
#   Matrix range     [8e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-02, 1e+00]
# Presolve time: 0.00s
# Presolved: 481 rows, 255 columns, 1431 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.940412e+00   0.000000e+00      0s
#        8    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.00 seconds (0.00 work units)
# ...

# %%
for k = 1:K
    println("γ_k: ", Ξ[k][1]' * Ξ[k][2])
end

# %% [markdown]
# # Test Column-Generation Procedure
#
# - use a underlying market f1, to generate $\Xi$,
# - then, create a surrogate market fa, initialized with one agent
# - use CG to iteratively add agents

# %%
m = 50
n = 20
K = 100 # how many revealed preferences pairs we have
ρ_vec = -3.5 .+ 4.3 .* rand(m)  # heterogeneous ρ ∈ [-2, -0.5]
# ρ_vec = -1.8 * ones(m)  # homogeneous ρ ∈ [-2, -0.5]
b = rand(n, m)
b ./= sum(b; dims=2)
e = ones(n)

# -----------------------------------------------------------------------
# setup market
# -----------------------------------------------------------------------
f0 = FisherMarket(m, n; ρ=ρ_vec, scale=30.0, sparsity=0.99)
linconstr = LinearConstr(1, n, ones(1, n), [1.0])

# -----------------------------------------------------------------------
# compute ground truth
# -----------------------------------------------------------------------
# Generate revealed preferences from the underlying market
f1 = copy(f0)
p₀ = ones(n) ./ (n)
x₀ = ones(n, m) ./ m
f1.x .= x₀
alg = HessianBar(
    n, m, p₀;
    linconstr=linconstr,
)
alg.linsys = :direct
include("./master.jl")
include("./pricing.jl")
include("./main.jl")
@info "Ground truth σ range" extrema(f1.σ)
Ξ = produce_revealed_preferences(alg, f1, K; seed=42);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0000 seconds
# FisherMarket initialized in 0.0001 seconds
# ┌ Info: Ground truth σ range
# │   extrema(f1.σ) = (-0.7769043605634877, 3.6551807224856168)
# └ @ Main /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X33sZmlsZQ==.jl:32

# %%
# Run standard CG
Random.seed!(42)
@time fa_cg, γ_ref_cg, hist_cg = cg(Ξ; max_iters=50, tol=1e-3, verbose=true, drop=false);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0002 seconds
# === Column Generation (standard) ===
#
# --- Iteration 1 (1 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 18.686515
#   Dual obj:   18.686515
#   Pricing σ:  8.2132,  rc: 22.639019
#   → Added agent 2
# --- Iteration 2 (2 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 15.44704
#   Dual obj:   15.44704
#   Pricing σ:  8.202,  rc: 19.501715
#   → Added agent 3
# --- Iteration 3 (3 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# ...

# %%
# Run multicut CG
Random.seed!(42)
@time fa_mc, γ_ref_mc, hist_mc = cg_multicut(Ξ; max_iters=15, tol=1e-3, verbose=true);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# === Column Generation (multicut) ===
#
# --- Iteration 1 (1 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 18.717246
#   Dual obj:   18.717246
#   Candidates: 100
#   → Added 100 agents (total: 101)
# --- Iteration 2 (101 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 1.530601
#   Dual obj:   1.530601
#   Dropped 81 zero-weight agents (20 remain)
#   Candidates: 100
#   → Added 100 agents (total: 120)
# --- Iteration 3 (120 agents) ---
# Set parameter Username
# ...

# %%
# Run least-squares CG
Random.seed!(42)
@time fa_lsq, γ_ref_lsq, hist_lsq = cg_lsq(Ξ; max_iters=50, tol=1e-3, verbose=true);
# Out:
# FisherMarket initialization started...
# FisherMarket cost matrix initialized in 0.0001 seconds
# FisherMarket initialized in 0.0001 seconds
# === Column Generation (least-squares) ===
#
# --- Iteration 1 (1 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 18.717246
#   Dual obj:   18.717246
#   Pricing σ:  0.0
#   → Added agent 2
# --- Iteration 2 (2 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
#   Primal obj: 1.632381
#   Dual obj:   1.632381
#   Dropped 1 zero-weight agents (1 remain)
#   Pricing σ:  0.0
#   → Added agent 2
# --- Iteration 3 (2 agents) ---
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# ...

# %%
# Compare CG vs Multicut CG vs LSQ CG
println("=== Comparison: CG vs Multicut vs LSQ ===\n")
@printf("%-20s %10s %10s %10s\n", "", "CG", "Multicut", "LSQ")
@printf("%-20s %10d %10d %10d\n", "Iterations", length(hist_cg[:primal_obj]), length(hist_mc[:primal_obj]), length(hist_lsq[:primal_obj]))
@printf("%-20s %10d %10d %10d\n", "Total agents", fa_cg.m, fa_mc.m, fa_lsq.m)

w_cg, _, _ = solve_master_problem(Ξ, γ_ref_cg[]; verbose=false)
w_mc, _, _ = solve_master_problem(Ξ, γ_ref_mc[]; verbose=false)
w_lsq, _, _ = solve_master_problem(Ξ, γ_ref_lsq[]; verbose=false)
@printf("%-20s %10d %10d %10d\n", "Nonzero agents", sum(w_cg .> 1e-6), sum(w_mc .> 1e-6), sum(w_lsq .> 1e-6))
@printf("%-20s %10.6f %10.6f %10.6f\n", "Final obj", hist_cg[:primal_obj][end], hist_mc[:primal_obj][end], hist_lsq[:primal_obj][end])
# Out:
# === Comparison: CG vs Multicut vs LSQ ===
#
#                              CG   Multicut        LSQ
# Iterations                   50         15          4
# Total agents                 51        159          1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-06-14
# Nonzero agents               48        159          1
# Final obj              0.294490   0.067910   1.632381

# %%
# Convergence plot
p1 = plot(hist_cg[:primal_obj], label="CG", lw=2, xlabel="Iteration", ylabel="Primal obj", title="Convergence")
plot!(p1, hist_mc[:primal_obj], label="Multicut", lw=2, ls=:dash)
plot!(p1, hist_lsq[:primal_obj], label="LSQ", lw=2, ls=:dot)
plot(p1, size=(600, 350))
# Out:
# <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>    <div id="01c8ba76-29f4-4b6f-802e-10df7c4cedd5" style="width:600px;height:350px;"></div>
#     <script>
#
#     Plotly.newPlot('01c8ba76-29f4-4b6f-802e-10df7c4cedd5', [
#     {
#         "showlegend": true,
#         "mode": "lines",
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.509920634920635,
#             "title": "",
#             "len": 0.8465504311961005,
#             "x": 0.9934383202099737
#         },
#         "name": "CG",
#         "yaxis": "y",
#         "legendgroup": "CG",
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 2
#         },
#         "y": [
#             18.686514614858563,
#             15.447039507468437,
#             12.706277130100341,
#             10.693767526667127,
#             9.036071416958597,
#             8.194621004765663,
# ...

# %%
pn = rand(n)
alg.p .= pn ./ sum(pn)
play!(alg, f1)
gn = sum(f1.x, dims=2)[:]
play!(alg, fa_mc)
ga = sum(fa_mc.x, dims=2)
[alg.p .* gn alg.p .* ga]
# Out:
# 20×2 Matrix{Float64}:
#  0.0419704   0.0419749
#  0.0464593   0.0464531
#  0.0509468   0.0509467
#  0.049019    0.049034
#  0.0474163   0.0474179
#  0.0715847   0.0715795
#  0.0392806   0.0392796
#  0.0577367   0.0577275
#  0.00905209  0.00908602
#  0.0371514   0.0371403
#  0.070283    0.0702749
#  0.0293866   0.029393
#  0.0580137   0.0580045
#  0.0339667   0.0339688
#  0.0601818   0.0601687
#  0.0748953   0.0748831
#  0.0481834   0.0481769
#  0.0592937   0.0593097
#  0.0420451   0.0420368
#  0.0731335   0.073144

# %%
# Out-of-sample: CG vs Multicut CG vs LSQ vs ground truth
println("=== Out-of-sample performance ===\n")
n_samples = 30
errs_cg = zeros(n_samples)
errs_mc = zeros(n_samples)
errs_lsq = zeros(n_samples)

for s in 1:n_samples
    pn = rand(n)
    pn ./= sum(pn)

    # Ground truth aggregate bidding vector
    alg.p .= pn
    play!(alg, f1)
    target = pn .* sum(f1.x, dims=2)[:]  # P g

    # CG prediction
    fitted_cg = zeros(n)
    for i in 1:fa_cg.m
        γ_i = compute_gamma(pn, Vector(fa_cg.c[:, i]), fa_cg.σ[i])
        fitted_cg .+= fa_cg.w[i] .* γ_i
    end

    # Multicut CG prediction
    fitted_mc = zeros(n)
    for i in 1:fa_mc.m
        γ_i = compute_gamma(pn, Vector(fa_mc.c[:, i]), fa_mc.σ[i])
        fitted_mc .+= fa_mc.w[i] .* γ_i
    end

    # LSQ CG prediction
    fitted_lsq = zeros(n)
    for i in 1:fa_lsq.m
        γ_i = compute_gamma(pn, Vector(fa_lsq.c[:, i]), fa_lsq.σ[i])
        fitted_lsq .+= fa_lsq.w[i] .* γ_i
    end

    errs_cg[s] = norm(fitted_cg .- target, Inf)
    errs_mc[s] = norm(fitted_mc .- target, Inf)
    errs_lsq[s] = norm(fitted_lsq .- target, Inf)
    @printf("  sample %2d:  CG=%.4f  MC=%.4f  LSQ=%.4f\n", s, errs_cg[s], errs_mc[s], errs_lsq[s])
end
println()
@printf("  Mean:       CG=%.6f  MC=%.6f  LSQ=%.6f\n", sum(errs_cg) / n_samples, sum(errs_mc) / n_samples, sum(errs_lsq) / n_samples)
@printf("  Max:        CG=%.6f  MC=%.6f  LSQ=%.6f\n", maximum(errs_cg), maximum(errs_mc), maximum(errs_lsq))
# Out:
# === Out-of-sample performance CG vs ground truth ===
#
#   sample  1:  CG L∞ = 0.004910,  Multicut L∞ = 0.000038
#   sample  2:  CG L∞ = 0.003884,  Multicut L∞ = 0.000010
#   sample  3:  CG L∞ = 0.008398,  Multicut L∞ = 0.000053
#   sample  4:  CG L∞ = 0.005344,  Multicut L∞ = 0.000065
#   sample  5:  CG L∞ = 0.010645,  Multicut L∞ = 0.000073
#   sample  6:  CG L∞ = 0.011793,  Multicut L∞ = 0.000077
#   sample  7:  CG L∞ = 0.005818,  Multicut L∞ = 0.000046
#   sample  8:  CG L∞ = 0.005371,  Multicut L∞ = 0.000013
#   sample  9:  CG L∞ = 0.023880,  Multicut L∞ = 0.000045
#   sample 10:  CG L∞ = 0.029800,  Multicut L∞ = 0.000081
#   sample 11:  CG L∞ = 0.003206,  Multicut L∞ = 0.000048
#   sample 12:  CG L∞ = 0.006957,  Multicut L∞ = 0.000039
#   sample 13:  CG L∞ = 0.011893,  Multicut L∞ = 0.000080
#   sample 14:  CG L∞ = 0.008410,  Multicut L∞ = 0.000069
#   sample 15:  CG L∞ = 0.008690,  Multicut L∞ = 0.000077
#   sample 16:  CG L∞ = 0.008577,  Multicut L∞ = 0.000065
# ...

# %% [markdown]
# # Can it be recovered by NLS?

# %%
include("./nls.jl")
# NLS with same number of agents as CG found
t_nls = 50  # use the number of nonzero CG agents
@info "Fitting $t_nls CES agents via NLS on $(length(Ξ)) observations, n=$n"

Y_nls, σ_nls, w_nls, γ_nls, res_nls = solve_nls(Ξ, t_nls; verbose=true, seed=42)
# Out:
# LoadError: InterruptException:
#
# in expression starting at /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/nls.jl:4
#
#
#
# Stacktrace:
#
#   [1] _include_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String, depmods::Vector{Any})
#
#     @ Base ./loading.jl:1058
#
#   [2] _tryrequire_from_serialized(modkey::Base.PkgId, path::String, ocachepath::String, sourcepath::String, depmods::Vector{Any})
#
#     @ Base ./loading.jl:1481
#
#   [3] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128)
#
#     @ Base ./loading.jl:1574
#
#   [4] _require(pkg::Base.PkgId, env::String)
#
#     @ Base ./loading.jl:1938
#
#   [5] __require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base ./loading.jl:1812
#
#   [6] #invoke_in_world#3
#
#     @ ./essentials.jl:926 [inlined]
#
#   [7] invoke_in_world
#
#     @ ./essentials.jl:923 [inlined]
#
#   [8] _require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base ./loading.jl:1803
# ...

# %%
# Evaluate NLS fit
obj_nls, residuals_nls, max_err_nls = evaluate_nls(Ξ, Y_nls, σ_nls, w_nls)


# Compare: per-observation L∞ error
nls_linf = [maximum(abs, residuals_nls[k, :]) for k in 1:K]
@info "NLS fit" obj = obj_nls max_err = max_err_nls
@info "CG final obj" cg_obj = history[:primal_obj][end]
println("NLS  Σ_k ||r_k||_∞ = $(round(sum(nls_linf), digits=6))")
println("CG   Σ_k ||s_k||_∞ = $(round(history[:primal_obj][end], digits=6))")
# Out:
# UndefVarError: `evaluate_nls` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X46sZmlsZQ==.jl:2

# %%
w_nls
# Out:
# UndefVarError: `w_nls` not defined

# %%
# Recover CES parameters and check on fresh prices (out-of-sample)
println("=== Out-of-sample comparison (NLS vs CG vs ground truth) ===\n")
for s in 1:10
    pn = rand(n)
    pn ./= sum(pn)

    # Ground truth
    alg.p .= pn
    play!(alg, f1)
    gn = sum(f1.x, dims=2)[:]
    target = pn .* gn

    # NLS prediction
    fitted_nls = zeros(n)
    for i in 1:t_nls
        z = Y_nls[i, :] .- σ_nls[i] .* log.(pn)
        γ_i = exp.(z .- logsumexp(z))
        fitted_nls .+= w_nls[i] .* γ_i
    end

    # CG prediction (using γ_ref and w_final)
    fitted_cg = zeros(n)
    for i in 1:length(w_final)
        if w_final[i] > 1e-8
            c_i = Vector(fa.c[:, i])
            σ_i = fa.σ[i]
            γ_i = compute_gamma(pn, c_i, σ_i)
            fitted_cg .+= w_final[i] .* γ_i
        end
    end

    err_nls = norm(fitted_nls .- target)
    err_cg = norm(fitted_cg .- target)
    @printf("  sample %2d: NLS err = %.6f, CG err = %.6f\n", s, err_nls, err_cg)
end
# Out:
# === Out-of-sample comparison (NLS vs CG vs ground truth) ===
# LoadError: UndefVarError: `@printf` not defined
#
# in expression starting at /Users/brent/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X51sZmlsZQ==.jl:34

# %%
# NLS σ values and weights
@info "NLS agents" σ = round.(σ_nls, digits=3) w = round.(w_nls, digits=4)
# Out:
# UndefVarError: `σ_nls` not defined
#
#
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ logging.jl:373 [inlined]
#
#  [2] top-level scope
#
#    @ ~/workspace/ExchangeMarket.jl/scripts/revealed/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:2
